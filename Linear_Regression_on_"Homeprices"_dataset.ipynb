# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3a4a2d43-62e2-402d-badb-0a6b86373afa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3a4a2d43-62e2-402d-badb-0a6b86373afa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving homeprices.csv to homeprices.csv

# %%
import pandas as pd
import io
df2 = pd.read_csv(io.BytesIO(uploaded['homeprices.csv']))  # Dataset is now stored in pandas framework

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df2 = pd.read_csv("homeprices.csv")
df2
plt.scatter(df2.area,df2.price,color='red',marker='+')

# %%
# importing the dataset
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
dataset = pd.read_csv("homeprices.csv")
dataset.head()
# data preprocessing
X = dataset.iloc[:, :-1].values #independent variable array
y = dataset.iloc[:,1].values #dependent variable vector
# splitting the dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=1/3,random_state=0)
# fitting the regression model
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,y_train) #actually produces the linear eqn for the data
# predicting the test set results
y_pred = regressor.predict(X_test) 
y_pred
y_test
# visualizing the results
#plot for the TRAIN
plt.scatter(X_train, y_train, color='red') # plotting the observation line
plt.plot(X_train, regressor.predict(X_train), color='blue') # plotting the regression line
plt.title("AREA v/s PRICES (Training set)") # stating the title of the graph

plt.show() # specifies end of graph
#plot for the TEST
plt.scatter(X_test, y_test, color='red') 
plt.plot(X_train, regressor.predict(X_train), color='blue') # plotting the regression line
plt.title("AREA v/s PRICES (Testing set)")


plt.show()
