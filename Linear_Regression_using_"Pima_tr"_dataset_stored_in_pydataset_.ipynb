# %%
 from pydataset import data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# !pip install pydataset
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 15.9 MB 7.0 MB/s
# ...
#   Created wheel for pydataset: filename=pydataset-0.2.0-py3-none-any.whl size=15939432 sha256=476c68c2e2ad130f7924703e7dc69aa235320746ce5b6ae9acc032e59081f741
#   Stored in directory: /root/.cache/pip/wheels/32/26/30/d71562a19eed948eaada9a61b4d722fa358657a3bfb5d151e2
# Successfully built pydataset
# ...

# %%
df = data('Pima.tr')
df.plot(kind="scatter",x="skin",y="bmi",alpha=.5,color='r')
plt.show()

# %%
X_train , X_test, y_train , y_test = train_test_split(df.skin,df.bmi)
plt.scatter(X_train,y_train,label="TRAINING DATA",color='b',alpha=.5)
plt.scatter(X_test,y_test,label="TESTING DATA",color='g',alpha=.7)
plt.legend()
plt.title("Test Train Show")
plt.show()

# %%
# !pip install pydataset
# Out:
# ...
#      |████████████████████████████████| 15.9 MB 14.2 MB/s
# ...
#   Created wheel for pydataset: filename=pydataset-0.2.0-py3-none-any.whl size=15939432 sha256=dda10afdc53cba553df215eb952ae9469204e3f16eb86964c459fcd54ed2fa53
#   Stored in directory: /root/.cache/pip/wheels/32/26/30/d71562a19eed948eaada9a61b4d722fa358657a3bfb5d151e2
# Successfully built pydataset
# ...

# %%
# !pip install pydata

# %%
LR = LinearRegression()
LR.fit(X_train.values.reshape(-1,1),y_train.values)
y_pred = LR.predict(X_test.values.reshape(-1,1))
plt.scatter(X_test,y_test,label="ACTUAL TEST DATA",color='g',alpha=.8)
plt.plot(X_test,y_pred,label="LINEAR REGRESSION",color='b')
plt.legend()
plt.show()

# %%
#Predict BMI Of Woman With Skin Fold 50
LR.predict(np.array([[50]]))[0]
# Out:
# 39.175224556416566

# %%
#Score this model
LR.score(X_test.values.reshape(-1,1),y_test.values)
# Out:
# 0.5124543996566673
